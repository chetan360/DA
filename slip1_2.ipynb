# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error

df = pd.read_csv("Position_Salaries.csv")
x =  np.array(df[['Salary']])
y = np.array(df['Level'])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size = 0.30)

regressor = LinearRegression()
regressor.fit(x_train,y_train)

y_train_pr = regressor.predict(x_train)


plt.scatter(x_train,y_train , color="blue")
plt.plot(x_train,y_train_pr , color="green")
plt.title("Regression(Train set)")
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color="blue")
y_pred = regressor.predict(x_test)
plt.plot(x_test,y_pred)
plt.show()

print('R2 score : %.2f' % r2_score(y_test,y_pred))
print('Mean Error :',mean_squared_error(y_test,y_pred))
# Out:
# R2 score : -4.99
# Mean Error : 3.990987200859801

# %%
def predict_level(salary):
    result = regressor.predict(np.array(salary).reshape(1,-1))
    return result[0]

for [salary,level] in zip(x,y):
    print("Salary :" , salary[0] ,'Actual :',level  , "Predicted : ", round(predict_level(salary)))
# Out:
# Salary : 45000 Actual : 1 Predicted :  3
# Salary : 50000 Actual : 2 Predicted :  3
# Salary : 60000 Actual : 3 Predicted :  3
# Salary : 80000 Actual : 4 Predicted :  3
# Salary : 110000 Actual : 5 Predicted :  4
# Salary : 150000 Actual : 6 Predicted :  4
# Salary : 200000 Actual : 7 Predicted :  4
# Salary : 300000 Actual : 8 Predicted :  5
# Salary : 500000 Actual : 9 Predicted :  7
# Salary : 1000000 Actual : 10 Predicted :  12
